# %%
import pandas as ps
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
file_path=r"C:\Users\Swetha\Downloads\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
wage_data=visa_df['prevailing_wage']
wage_non_outliers=visa_df['prevailing_wage']
plt.figure(figsize=(14,6))
plt.hist(wage_data)
plt.hist(wage_non_outliers)
plt.show()

# %%
l=[]

# %%
d={'name':['manish','smart swetha','maha','dhruva'],'age':[50,20,3,1],'height':[5.10,5.11,2.00,1.11],'color':['black and white','natural','same as mumma','same as mumma'],'gender':['male','female','female','male'],'brain':['not in working stage','100 iq','smart','intelligent']}
x=pd.DataFrame(d)
x
# Out:
#            name  age  height            color  gender                 brain
# 0        manish   50    5.10  black and white    male  not in working stage
# 1  smart swetha   20    5.11          natural  female                100 iq
# 2          maha    3    2.00    same as mumma  female                 smart
# 3        dhruva    1    1.11    same as mumma    male           intelligent

# %%
manish_history={'whatsapp':[015600,011900,020600,025500,005200,035100,062400],'youtube':[005300,002100,001100

# %%
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
yr_data=visa_df['yr_of_estab']
plt.boxplot(yr_data,vert=False)
plt.show()
#vert is used for the direction of the boxplot vert=trie vertical false horizontal

# %%
for i in num_columns:
    data=visa_df[i]
    plt.boxplot(data,vert=False)
    plt.show()

# %%
data=visa_df['prevailing_wage']
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.hist(data,bins=20)
plt.subplot(1,2,2)
plt.boxplot(data,vert=False)
plt.show()

# %%
num=num_columns
for i in range(len(num) ):
    data=visa_df[num[i]]
    plt.figure(figsize=(16,6))
    plt.subplot(2,2,i+1)
    plt.hist(data,bins=20)
    plt.subplot(2,2,i+2)
    plt.boxplot(data,vert=False)
    plt.show()

# %% [markdown]
# **finding the outliers**
# - We already know that outliers avialble less than Q1-1.5IQR and Q3+1.5IQR
# - -
# Step-1
#   -  :-
# Calculate Q1= 2
# - 5- c
# Calculate 2=
# - 5- 0p
# CalculateQ3=
# -  - 75p
# St
# - e p-2:
# Calculate IQR=
#   - Q3-Q1
#
#  - S- tep-3:
# Calculate LB= Q1
# - -- 1.5*IQR
# Calculate UB=Q
# - 3- +1.5*IQ
# - R- c
# Step-4:
# Con1= wa
# - g- e data <LB
# Con2= w
# - a- ge data >UB
# Con3= con1 or-and con2 (use bitw
# - i- se operator)
# Step-5: Data [con3]

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.quantile(wage_data,0.50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data<lb
con2=wage_data>ub
con3=con1|con2 # | its an bitwise or
len(visa_df[con3])
outliers_data=visa_df[con3]
len(outliers_data)
# Out:
# 427

# %%
visa_df[con3]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.quantile(wage_data,0.50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data>lb
con2=wage_data<ub
con4=con1&con2  # bitwise and
len(visa_df[con3])
non_outliers_data=visa_df[con4]
non_outliers_data
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(non_outliers_data)
# Out:
# 25053

# %%
visa_df[con4]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
wage_data=outliers_data['prevailing_wage']
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.suptitle('comparision of outliers data with historam and box plot')
plt.hist(wage_data,bins=20)
plt.subplot(1,2,2)
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
wage_data=non_outliers_data['prevailing_wage']
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.suptitle('comparision of non outliers data with historam and box plot')
plt.hist(wage_data,bins=20)
plt.subplot(1,2,2)
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
plt.subplot(1,2,1).hist(wage_data)
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.show()

# %%
# Fill the outliers of wage data with wage median
# 427 outliers
# 427 should replace with meadin value
# again draw the plots

# %%
len(outliers_data)
# Out:
# 427

# %%
median=np.percentile(visa_df['prevailing_wage'],50)
q1=np.percentile(wage_data,25)
q2=np.quantile(wage_data,0.50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data>lb
con2=wage_data<ub
out=[]
for i in visa_df['prevailing_wage']:
    if i<lb or i>ub:
        out.append(median)
    else:
        out.append(median)

visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64
