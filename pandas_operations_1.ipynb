# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **read the data**
# - here we are using the visa dataset
# - which is in the form of csv file:comma separated value
# - in order to read any dataset
# - - we nneed directort
#   - filename
#   - type

# %%
file_path=r"C:\Users\Swetha\Downloads\Visadataset.csv"

# %%
import pandas as pd
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
m=pd.read_csv(file_path,sep=',')
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 m=pd.read_csv(file_path,sep=',')
#       2 m
#
# NameError: name 'file_path' is not defined

# %% [markdown]
# **data quick checks**
# * head
# * tail
# * shape
# * size
# * columns
# * dtypes
# * info
# * take
# * loc
# * iloc

# %%
#to find the methids of the dataframe we use dir(visa_df) syntax
dir(visa_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.head(11)
# Out:
#    case_id      continent education_of_employee has_job_experience  \
# 0   EZYV01           Asia           High School                  N
# 1   EZYV02           Asia              Master's                  Y
# 2   EZYV03           Asia            Bachelor's                  N
# 3   EZYV04           Asia            Bachelor's                  N
# 4   EZYV05         Africa              Master's                  Y
# 5   EZYV06           Asia              Master's                  Y
# 6   EZYV07           Asia            Bachelor's                  N
# 7   EZYV08  North America            Bachelor's                  Y
# 8   EZYV09           Asia            Bachelor's                  N
# 9   EZYV10         Europe             Doctorate                  Y
# 10  EZYV11           Asia              Master's                  N
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                      N            14513         2007                 West
# ...

# %%
#tail
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.tail(11)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
#shape
visa_df.shape
# Out:
# (25480, 12)

# %%
print(f'the numberof rows in visa data : {visa_df.shape[0]}')
print(f'the numberof rows in visa data : {visa_df.shape[1]}')
# Out:
# the numberof rows in visa data : 25480
# the numberof rows in visa data : 12

# %%
#**size**
#rows*columns
visa_df.size
# Out:
# 305760

# %%
visa_df.shape[0]*visa_df.shape[1]
# Out:
# 305760

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
len(visa_df.columns)
# Out:
# 12

# %% [markdown]
# #**dtypes**
# - it will provide each column data type
# - object means string data type(categorical)
# - int64,int34,int128,float64 (numerical)
# - dtypes always give in series

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **task-1**
# - i want to create two lists
# - one is categorical column list
# - second one is numerical column list
# - using dtypes
# - whenever you want to create any list from series
# - first convert the series into a dictinory
# - when you convert it becomes a key:value pair
# - iterate through dictionary
# - if the value==object type,then keep that corresponding key in one list
# - else keep that variable in order list

# %%
data_types=visa_df.dtypes
dict(data_types)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
visa_df.info
# Out:
# <bound method DataFrame.info of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
data_types=visa_df.dtypes
dict(data_types)
cat_list=[]
num_list=[]
for keys,values in dict(visa_df.dtypes).items():
    if values=='object':
        cat_list.append(keys)
    else:
        num_list.append(keys)

cat_list
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
for i,j in dict(visa_df.dtypes).items():
    print(i,j)
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# no_of_employees int64
# yr_of_estab int64
# region_of_employment object
# prevailing_wage float64
# unit_of_wage object
# full_time_position object
# case_status object

# %%
cols,data_types=[],[]
for keys,values in dict(visa_df.dtypes).items():
    cols.append(keys)
    data_types.append(values)

pd.DataFrame(zip(cols,data_types),columns=['column','data type'])
# Out:
#                    column data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
l1=['swetha','man','sub','rrr']
l2=[22,33,44,55]
dict={}
for i,j in zip(l1,l2):
    dict([].append(i))
    dict([1].append(j))


print(dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       3 dict={}
#       4 for i,j in zip(l1,l2):
# ----> 5     dict([keys].append(i))
#       6     dict([1].append(j))
#       9 print(dict)
#
# TypeError: 'dict' object is not callable

# %%
import pandas as  pd
columns=['swetha','man','sub','rrr']
dt=['float','float','float','float']
dict={}
dict['columns']=columns
dict['data types']=dt
pd.DataFrame(dict)
# Out:
#   columns data types
# 0  swetha      float
# 1     man      float
# 2     sub      float
# 3     rrr      float

# %% [markdown]
# - we can not create a dataframe using these two lists
# - because these two lists are not in equal length
# - If you want to create a dataframe , then we need to make two lists has equal length
# - then you need to question yourslef
# - making equal lenght required or not
# - if it is require how?

# %% [markdown]
# **create columns dataframes**

# %%
num_df=pd.DataFrame(num_list,columns=['numerical_column'])
num_df.to_csv('numerical_column_df.csv',index=False)

# %%
cat_df=pd.DataFrame(cat_list,columns=['categorical_column'])
cat_df.to_csv('cateforical_column_df.csv',index=False)

# %% [markdown]
# **task2**

# %%
dict(visa_df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dict(visa_df.dtypes)
#
# NameError: name 'visa_df' is not defined

# %%
file_path=r"C:\Users\Swetha\Downloads\Visadataset.csv"

# %%
import pandas as pd
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
dict(visa_df.dtypes)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
dict(visa_df.dtypes).values()
# Out:
# dict_values([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'), dtype('O'), dtype('O'), dtype('O')])

# %%
cols,data_type=[],[]
for key,value in dict(visa_df.dtypes).items():
    cols.append(value)
    data_type.append(key)

visa=zip(cols,data_type)
pd.DataFrame(visa,columns=['columns','data_type'])
# Out:
#     columns              data_type
# 0    object                case_id
# 1    object              continent
# 2    object  education_of_employee
# 3    object     has_job_experience
# 4    object  requires_job_training
# 5     int64        no_of_employees
# 6     int64            yr_of_estab
# 7    object   region_of_employment
# 8   float64        prevailing_wage
# 9    object           unit_of_wage
# 10   object     full_time_position
# 11   object            case_status

# %%
#dataframe using dictionary
d1={'name':'swetha','age':20,'gender':'female','qualifiaction':'UG'}
for i,j in d1.items():
    print(i,' : ',j)
# Out:
# name  :  swetha
# age  :  20
# gender  :  female
# qualifiaction  :  UG

# %% [markdown]
# **task3**
# - we can create the dataframe using dictionary also
# - here in dictionary no need of mention of column names again
# - the keys itself behave like an column names in an dataframe

# %%
d2={'names':['n1','n2','n3','n4','n5'],'values':[11,22,33,44,55]}
d2
# Out:
# {'names': ['n1', 'n2', 'n3', 'n4', 'n5'], 'values': [11, 22, 33, 44, 55]}

# %%
pd.DataFrame(d2)
# Out:
#   names  values
# 0    n1      11
# 1    n2      22
# 2    n3      33
# 3    n4      44
# 4    n5      55

# %% [markdown]
# - we need to convert 2 lists into the dictionary and then make that dictionary into a dataframe

# %%
d3={}
d3['columns']=cols
d3['data types']=data_type
pd.DataFrame(d3)


#anotherway
pd.DataFrame(zip(cols,data_type),columns=['columns','data types'])
# Out:
#     columns             data types
# 0    object                case_id
# 1    object              continent
# 2    object  education_of_employee
# 3    object     has_job_experience
# 4    object  requires_job_training
# 5     int64        no_of_employees
# 6     int64            yr_of_estab
# 7    object   region_of_employment
# 8   float64        prevailing_wage
# 9    object           unit_of_wage
# 10   object     full_time_position
# 11   object            case_status

# %%
#dataframe name=vvisa_df
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **isnull**

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
#to find number of missing values in the each column in a dataset we use isnull().sum()
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# - list  df
# - dict df
# - list dict df
# - dict list df

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# - methods
# - head
# - tail
# - shape
# - size
# - columns
# - dtypes

# %% [markdown]
# **isnull**
# - null menas the element is missing also known as missing values
# - isnull means the question to comp that the data is missing or not
# - computer will respond to that question in True or False way
# - true=data(value) missed
# - false=the value is not missed

# %%
visa_df.isnull()
#to check the missing number if missing we can see true else we can see false
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# - take dtypes
# - convert into dictionary
# - create two lists
# - create 2 dataframes
