# %%
import pandas as pd
visa_df=pd.read_csv('visadataset.csv')
visa_df

# %%
types=dict(visa_df.dtypes)
cat_columns=[key for key,value in types.items() if value=='object']
num_column=[key for key,value in types.items() if value!='object']
cat_columns
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cat_colums=visa_df.select_dtypes(include=='object').columns
num_columns=visa_df.select_dtypes(exclude=='object').columns
cat_columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cat_colums=visa_df.select_dtypes(include=='object').columns
#       2 num_columns=visa_df.select_dtypes(exclude=='object').columns
#       3 cat_columns
#
# NameError: name 'include' is not defined

# %%
visa_df['continent'] #series
visa_df[['continent']]  #dataframe 
visa_df.continent  #series
visa_df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
c=['continent','case_status']
visa_df[c]
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %% [markdown]
# **task1**

# %% [markdown]
# **unique**
# - unique will provide the how many unique items are present in the particular column

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
len(visa_df['continent'].unique())
# Out:
# 6

# %% [markdown]
# **nunique**
# - fives the count of number of unique items

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %%
visa_df['continent']=='Asia'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: continent, Length: 25480, dtype: bool

# %%
condition=visa_df['continent']=='Asia'
#dataframs[condition]
visa_df[condition]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#read the column with specific column
#then apply the condition ==python provides bool values(true or false)
#in order to retrieve the  data syntax=dataframe[condition]
visa_df['continent']
visa_df['continent']=='Asia'
con=visa_df['continent']=='Asia'
visa_df[con]
len(visa_df[con])
# Out:
# 16861

# %%
condition=visa_df['continent']=='Asia'
visa_df[condition]
for i in visa_df['continent'].unique():
    condition=visa_df['continent']==i
    print(visa_df[condition])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
for i in visa_df['continent'].unique():
    condition=visa_df['continent']==i
    count=(len(visa_df[condition]))
    print(f'the count of {i} apperance is {count}')
# Out:
# the count of Asia apperance is 16861
# the count of Africa apperance is 551
# the count of North America apperance is 3292
# the count of Europe apperance is 3732
# the count of South America apperance is 852
# the count of Oceania apperance is 192

# %% [markdown]
# **task2**

# %%
import pandas as pd
l=[]
continents=visa_df['continent'].unique()
for i in visa_df['continent'].unique():
    condition=visa_df['continent']==i
    count=(len(visa_df[condition]))
    l.append(count)

print(l)

df=pd.DataFrame(l)
print(df)
continents_df=pd.DataFrame(zip(continents,l),columns=['continents','number of applicants'])
continents_df.to_csv('continents_df.csv',index=False)
# Out:
# [16861, 551, 3292, 3732, 852, 192]
#        0
# 0  16861
# 1    551
# 2   3292
# 3   3732
# 4    852
# 5    192

# %%
**value_counts**

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
import pandas as pd
df=pd.DataFrame(l)
df
# Out:
#        0
# 0  16861
# 1    551
# 2   3292
# 3   3732
# 4    852
# 5    192

# %% [markdown]
# ## class revise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv('visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **dividing the dataset into categorical and numerical**

# %%
types=dict(visa_df.dtypes)
cat_column=[key for key,value in types.items() if value=='object']
num_column=[key for key,value in types.items() if value!='object']
print(cat_column)
print('......')
print(num_column)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ......
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **selecting specific columns**

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df['continent']   #series
visa_df[['continent']] #dataframe
visa_df.continent #series
visa_df.loc[:,['continent']]

# %%
cols=['continent','unit_of_wage']
visa_df[cols]
# Out:
#       continent unit_of_wage
# 0          Asia         Hour
# 1          Asia         Year
# 2          Asia         Year
# 3          Asia         Year
# 4        Africa         Year
# ...         ...          ...
# 25475      Asia         Year
# 25476      Asia         Year
# 25477      Asia         Year
# 25478      Asia         Year
# 25479      Asia         Year
#
# [25480 rows x 2 columns]

# %% [markdown]
# **task1**

# %% [markdown]
# - to find number of applicants continent wise we use **unique**
# - unique provide us the number if unique items in a particular column

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
len(visa_df['continent'].unique())
# Out:
# 6

# %% [markdown]
# - len() and nunique functions the same

# %%
visa_df['continent']=='Asia'
len(visa_df['continent']=='Asia')
# Out:
# 25480

# %%
for i in visa_df['continent'].unique():
    condition=visa_df['continent']==i
    count_each_continent=len(visa_df[condition])
    print(f'the count of {i} is {count_each_continent}')
# Out:
# the count of Asia is 16861
# the count of Africa is 551
# the count of North America is 3292
# the count of Europe is 3732
# the count of South America is 852
# the count of Oceania is 192

# %% [markdown]
# **task2**
# - now insteas of print(count) take an empty list
# - save all the valuesin to a list
# - we had  the unique continent list and a count list
# - create a dataframe using those list

# %%
continents=visa_df['continent'].unique()
count_list=[]
for i in visa_df['continent'].unique():
    condition=visa_df['continent']==i
    count_list.append(len(visa_df[condition]))

count_list
df=pd.DataFrame(zip(continents,count_list),columns=['continent','number '])
df
# Out:
#        continent  number
# 0           Asia    16861
# 1         Africa      551
# 2  North America     3292
# 3         Europe     3732
# 4  South America      852
# 5        Oceania      192

# %%
#value_counts
c=visa_df['continent'].value_counts()
c
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
type(c)
# Out:
# pandas.core.series.Series

# %%
keys=c.keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values=c.values
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
dd=pd.DataFrame(zip(keys,values),columns=['labels','count'])

dd.to_csv('continentssss.csv',index=False)
